# %% [markdown]
# Importing Necessary Libraries & modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read CSV data

# %%
df = pd.read_csv("/content/Covid-19.csv")

# %%
# head - displays only first 5-data

df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %% [markdown]
# # **Data Pre-processing**

# %%
# Shape - displays (rows & column) in form of "tuple"

print("(rows, Columns) :", df.shape)
# Out:
# (rows, Columns) : (1048575, 21)

# %%
# columns - Display entire columns name

df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
# info - Gives information about column, Non-null(count) & Dtype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
# describe - mathematical stats of data

df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# std    1.191288e+01  1.690739e+01  4.751073e+01  5.424242e+00  5.132258e+00
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  3.000000e+01  2.000000e+00  2.000000e+00  2.000000e+00
# 50%    2.000000e+00  4.000000e+01  9.700000e+01  2.000000e+00  2.000000e+00
# 75%    2.000000e+00  5.300000e+01  9.700000e+01  2.000000e+00  2.000000e+00
# max    9.900000e+01  1.210000e+02  9.800000e+01  9.800000e+01  9.800000e+01
#
#              ASTHMA       INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# count  1.048575e+06  1.048575e+06  1.048575e+06   1.048575e+06
# mean   2.242626e+00  2.298132e+00  2.128989e+00   2.435143e+00
# std    5.114089e+00  5.462843e+00  5.236397e+00   6.646676e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# 50%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# 75%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# max    9.800000e+01  9.800000e+01  9.800000e+01   9.800000e+01
#
#        CARDIOVASCULAR       OBESITY  RENAL_CHRONIC       TOBACCO  \
# count    1.048575e+06  1.048575e+06   1.048575e+06  1.048575e+06
# mean     2.261810e+00  2.125176e+00   2.257180e+00  2.214333e+00
# std      5.194850e+00  5.175445e+00   5.135354e+00  5.323097e+00
# min      1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# 25%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# 50%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# 75%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# max      9.800000e+01  9.800000e+01   9.800000e+01  9.800000e+01
#
#        CLASIFFICATION_FINAL           ICU
# count          1.048575e+06  1.048575e+06
# mean           5.305653e+00  7.955397e+01
# std            1.881165e+00  3.682307e+01
# min            1.000000e+00  1.000000e+00
# 25%            3.000000e+00  9.700000e+01
# 50%            6.000000e+00  9.700000e+01
# 75%            7.000000e+00  9.700000e+01
# max            7.000000e+00  9.900000e+01

# %%
# duplicated - Displays count of duplicate entries

df.duplicated().sum()
# Out:
# 812049

# %%
# dropping duplicates

df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# 0

# %%
# Returns unique value of each column

df.nunique()
# Out:
# USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               401
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     121
# PREGNANT                  4
# DIABETES                  3
# COPD                      3
# ASTHMA                    3
# INMSUPR                   3
# HIPERTENSION              3
# OTHER_DISEASE             3
# CARDIOVASCULAR            3
# OBESITY                   3
# RENAL_CHRONIC             3
# TOBACCO                   3
# CLASIFFICATION_FINAL      7
# ICU                       4
# dtype: int64

# %% [markdown]
# *  Since in above data, unique values shows that most data are in categorical-nature

# %%
# checking for null-values

df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %% [markdown]
# *   Now we see there are no null values,
# but values 97,98 and 99 are considered as null as per data info.

# %% [markdown]
# **Creating table for feature with null value percentage:**

# %%
# we are calculating percentage which have val - 97,98,99
perc=[]

for col in list(df.columns):
   perc.append(round(len(df[(df[col]==97)| (df[col]==98) | (df[col]==99)])/len(df)*100,2))

# %%
# Replacing column index:(0,1) into (Feature, Percentage)
# sorting them by percentage - desc wise

sort_perc = ((pd.DataFrame([df.columns,perc]).T).rename(columns={0:"Feature",1:"Percentage"})).sort_values(by="Percentage",ascending=False)
sort_perc
# Out:
#                  Feature Percentage
# 8               PREGNANT      55.58
# 20                   ICU      44.62
# 5                INTUBED      44.56
# 6              PNEUMONIA       3.04
# 14         OTHER_DISEASE       1.84
# 12               INMSUPR       1.24
# 9               DIABETES        1.2
# 18               TOBACCO       1.16
# 13          HIPERTENSION       1.11
# 15        CARDIOVASCULAR        1.1
# 16               OBESITY       1.08
# 17         RENAL_CHRONIC       1.07
# 10                  COPD       1.07
# 11                ASTHMA       1.06
# 7                    AGE       0.13
# 1           MEDICAL_UNIT        0.0
# 4              DATE_DIED        0.0
# 3           PATIENT_TYPE        0.0
# 2                    SEX        0.0
# 19  CLASIFFICATION_FINAL        0.0
# 0                  USMER        0.0

# %% [markdown]
# *   In the above dataframe we can clearly see that ICU,INTUBED and PREGNANT features has more null values.

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
# Dropping ICU, INTUBED & PREGNANT columns
# Taking only useful col

useful_cols=['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED',
       'PNEUMONIA', 'AGE', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
       'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
       'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL']
df = df[useful_cols]

# %% [markdown]
# *   Replacing the column values with nan where values equal to 97,98 and 99.

# %%
# Replacing 97,98,99 as "nan"

df=df.replace({
    'USMER':{97:np.nan,98:np.nan,99:np.nan},
    'MEDICAL_UNIT':{97:np.nan,98:np.nan,99:np.nan},
    'SEX':{97:np.nan,98:np.nan,99:np.nan},
    'PATIENT_TYPE':{97:np.nan,98:np.nan,99:np.nan},
    'DATE_DIED':{97:np.nan,98:np.nan,99:np.nan},
    'PNEUMONIA':{97:np.nan,98:np.nan,99:np.nan},
    'AGE':{97:np.nan,98:np.nan,99:np.nan},
    'DIABETES':{97:np.nan,98:np.nan,99:np.nan},
    'COPD':{97:np.nan,98:np.nan,99:np.nan},
    'ASTHMA':{97:np.nan,98:np.nan,99:np.nan},
    'INMSUPR':{97:np.nan,98:np.nan,99:np.nan},
    'HIPERTENSION':{97:np.nan,98:np.nan,99:np.nan},
    'OTHER_DISEASE':{97:np.nan,98:np.nan,99:np.nan},
    'CARDIOVASCULAR':{97:np.nan,98:np.nan,99:np.nan},
    'OBESITY':{97:np.nan,98:np.nan,99:np.nan},
    'RENAL_CHRONIC':{97:np.nan,98:np.nan,99:np.nan},
    'TOBACCO':{97:np.nan,98:np.nan,99:np.nan},
    'CLASIFFICATION_FINAL':{97:np.nan,98:np.nan,99:np.nan}
})

# %%
df.isnull().sum()
# Out:
# USMER                      0
# MEDICAL_UNIT               0
# SEX                        0
# PATIENT_TYPE               0
# DATE_DIED                  0
# PNEUMONIA               7187
# AGE                      308
# DIABETES                2840
# COPD                    2529
# ASTHMA                  2506
# INMSUPR                 2926
# HIPERTENSION            2620
# OTHER_DISEASE           4362
# CARDIOVASCULAR          2603
# OBESITY                 2554
# RENAL_CHRONIC           2531
# TOBACCO                 2738
# CLASIFFICATION_FINAL       0
# dtype: int64

# %% [markdown]
# *  Now Dropping rows where nan values are present

# %%
# Drop na-values from useful columns

df=df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# PNEUMONIA               0
# AGE                     0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# dtype: int64

# %% [markdown]
# DATE_DIED:
# *   Replacing "9999-99-99" to 0 & 1 in DATE_DIED column
#     *  0 ---> Not Died
#     *  1 ---> Died

# %%
# Classifying DATE_DIED column as 0 and 1

df.loc[df.DATE_DIED=="9999-99-99","DATE_DIED"]=0
df.loc[df.DATE_DIED!=0,"DATE_DIED"]=1

# %%
# Now Renaming DATE_DIED-col into DIED-col

df.rename(columns={"DATE_DIED":"DIED"},inplace=True)
# Out:
# <ipython-input-93-940249d25e54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"DATE_DIED":"DIED"},inplace=True)

# %%
# Percentage Calculation of alive(0)  or  not alive(1)

df.DIED.value_counts(normalize=True)*100
# Out:
# 0    66.885973
# 1    33.114027
# Name: DIED, dtype: float64

# %% [markdown]
# * 0 ----> 67 % people is Alive
# * 1 ----> 33 % people Died (COVID)

# %% [markdown]
# **Binning AGE feature:**

# %%
df.AGE=pd.cut(df.AGE,bins=[1,13,21,40,100],labels=["childhood","teenage","adult","elder"])

# %%
cols=['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'PNEUMONIA',
       'AGE', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION',
       'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC',
       'TOBACCO', 'CLASIFFICATION_FINAL']

# %% [markdown]
# **Listing categorical feature:**

# %%
categ_cols = [col for col in cols if df[col].nunique()<15]
categ_cols
# Out:
# ['USMER',
#  'MEDICAL_UNIT',
#  'SEX',
#  'PATIENT_TYPE',
#  'PNEUMONIA',
#  'AGE',
#  'DIABETES',
#  'COPD',
#  'ASTHMA',
#  'INMSUPR',
#  'HIPERTENSION',
#  'OTHER_DISEASE',
#  'CARDIOVASCULAR',
#  'OBESITY',
#  'RENAL_CHRONIC',
#  'TOBACCO',
#  'CLASIFFICATION_FINAL']

# %% [markdown]
# # **Data Visualization**

# %%
for col in categ_cols:
    plt.figure(figsize=(15,10))
    sns.countplot(x=df[col],hue=df["DIED"])

# %% [markdown]
# # **Some Important Insights from plots**
#
#
# > * Male died more than Female
# > * Death more in patient type- Hospitalization
# > * Death cases more in Age between 40-100.

# %% [markdown]
# **Converting categorical data to numerical:**

# %%
df=pd.get_dummies(data=df,columns=["AGE"])

# %% [markdown]
# > * X=Independent feature
# > * y=Dependent feature

# %%
X=df.drop(["DIED"],axis=1)
y=df["DIED"].astype(int)

# %% [markdown]
# # **Data Scaling**

# %% [markdown]
# **Importing Necessary libraries to perform Model**

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# # **Logistic Regression**

# %% [markdown]
# **Importing Necessary libraries to perform Model**

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred_lr=lr.predict(X_test)

acc_lr=metrics.accuracy_score(y_test,y_pred_lr)
print("Accuracy of Logistic Regression model is:",acc_lr)
# Out:
# Accuracy of Logistic Regression model is: 0.7814753189129229

# %% [markdown]
# # **Random Forest Classifier**

# %% [markdown]
# **Importing Necessary libraries to perform Model**

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred_rf=rf.predict(X_test)

acc_rf=metrics.accuracy_score(y_test,y_pred_rf)
print("Accuracy of Random Forest model is:",acc_rf)
# Out:
# Accuracy of Random Forest model is: 0.8007225195245162

# %% [markdown]
# # **Gradient Boosting Classifier**

# %% [markdown]
# **Importing Necessary libraries to perform Model**

# %%
from sklearn import metrics
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()
gb.fit(X_train,y_train)
y_pred_gb=gb.predict(X_test)

acc_gb=metrics.accuracy_score(y_test,y_pred_gb)
print("Accuracy of Gradient Boosting model is:",acc_gb)
# Out:
# Accuracy of Gradient Boosting model is: 0.8038254560717123

# %% [markdown]
# # **Decision Tree Classifier**

# %% [markdown]
# **Importing Necessary libraries to perform Model**

# %%
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred_dt=dt.predict(X_test)

acc_dt=metrics.accuracy_score(y_test,y_pred_dt)
print("Accuracy of Decision Tree model is:",acc_dt)
# Out:
# Accuracy of Decision Tree model is: 0.7984140546536553

# %% [markdown]
# # **Comparison of Various Models**

# %% [markdown]
# # *Results*

# %%
from sklearn import metrics
from sklearn.svm import SVC

# %%
pd.DataFrame({"Model":["Logistic Regression","Random Forest Classifier","Gradient Boosting Classifier","Decision Tree Classifier"],
             "Accuracy":[acc_lr,acc_rf,acc_gb,acc_dt]})
# Out:
#                           Model  Accuracy
# 0           Logistic Regression  0.781475
# 1      Random Forest Classifier  0.800723
# 2  Gradient Boosting Classifier  0.803825
# 3      Decision Tree Classifier  0.798414
